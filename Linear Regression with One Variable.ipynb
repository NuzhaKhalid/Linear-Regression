# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ex1data1.txt', header = None)
df.columns = ['Population', 'Profit']

# %%
x = df.iloc[:,0]
y = df.iloc[:,1]

plt.figure(figsize=(8, 6))
plt.scatter(x, y ,marker='x', color='red')

plt.title('Scatter plot of training data')
plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.ylim(-5, 25)

plt.show()

# %%
m = len(x)
def CostFunction(X, y ,theta):
    J = np.power((np.dot(X, theta) - y), 2)
    J = np.sum(J) / (2 * m)
    return J

# %%
x = np.stack([np.ones(m), x], axis=1)

# %%
def univariate_gradient_descent(iterations, alpha):
    theta = [0, 0]
    J = []
    for i in range(iterations):
        h = x.dot(theta)    #Prediction = Data Matrix * Parameters
        theta = theta - alpha * (1/m) * (np.dot((h - y), x))
        J.append(CostFunction(x, y, theta))
    return J, theta

iterations = 1000
alpha = 0.01
J, theta_vectorized = univariate_gradient_descent(iterations, alpha)
print(theta_vectorized)
# Out:
# [-3.24140214  1.1272942 ]

# %%
plt.figure(figsize=(8, 6))
plt.ylim(-5, 25)
plt.scatter(x[:,1], y, marker='x', color='red')
plt.title('Training data with linear regression fit')
plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.plot(x[:,1], x.dot(theta_vectorized),color='blue')
plt.show()
